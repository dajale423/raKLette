# %%
import sys
sys.path.insert(0,'/home/djl34/kl_git/scripts')
from notebook_imports import *
import einops

client = Client()
# Out:
# /home/djl34/mambaforge/envs/raklette/lib/python3.9/site-packages/dask/dataframe/_pyarrow_compat.py:17: FutureWarning: Minimal version of pyarrow will soon be increased to 14.0.1. You are using 11.0.0. Please consider upgrading.
#   warnings.warn(

# %% [markdown]
# # Try for chromosome 22

# %%
chrom = 22
filename = os.path.join(KL_data_dir, f"whole_genome/p/{chrom}/_metadata")
rate = dd.read_parquet(filename.split("_metadata")[0])

# %%
rate_neutral = rate[~rate["Neutral"].isna()].compute()
rate_neutral = rate_neutral.reset_index(drop = True)
# Out:
# /home/djl34/mambaforge/envs/raklette/lib/python3.9/site-packages/dask/dataframe/_pyarrow_compat.py:17: FutureWarning: Minimal version of pyarrow will soon be increased to 14.0.1. You are using 11.0.0. Please consider upgrading.
#   warnings.warn(

# %%
rate_neutral_shuffled = rate_neutral.sample(frac=1).reset_index(drop=True)

# %%
rate_neutral.head()
# Out:
#         Pos     mu Allele_ref Allele  mu_index  AN_total_interpolate  \
# 0  26886471  0.117          A      G        10             1135326.0
# 1  26886471  0.013          A      T         0             1135290.0
# 2  26886471  0.020          A      C         1             1135290.0
# 3  26886472  0.051          A      G         4             1135290.0
# 4  26886472  0.030          A      C         2             1135290.0
#
#    AC_total  filter_int  AF_gnomADv3  AF_ukb        AF  window_100bp  \
# 0       3.0           4      0.00002     NaN  0.000003        156333
# 1       0.0           4          NaN     NaN  0.000000        156333
# 2       0.0           4          NaN     NaN  0.000000        156333
# 3       0.0           4          NaN     NaN  0.000000        156333
# 4       0.0           4          NaN     NaN  0.000000        156333
#
#    polymorphic  polymorphic_100bp  Neutral    cds  Freq_bin_9  Freq_bin_10  \
# 0            1                 44      1.0  False           3            3
# 1            0                 44      1.0  False           0            0
# 2            0                 44      1.0  False           0            0
# 3            0                 44      1.0  False           0            0
# 4            0                 44      1.0  False           0            0
#
#         p_9    E[p_9]  Var[p_9]  p_9_reverse_log  E[p_9_reverse_log]  \
# 0 -0.932277 -0.779518  0.006429    -2.298098e+00           -0.541898
# 1 -0.965322 -0.966130  0.000019     0.000000e+00           -0.140227
# 2 -0.946241 -0.948165  0.000070    -5.551115e-16           -0.194174
# 3 -0.872834 -0.883462  0.000841    -2.220446e-16           -0.351029
# 4 -0.922983 -0.926907  0.000198    -4.440892e-16           -0.250862
#
#    Var[p_9_reverse_log]  p_2    E[p_2]  Var[p_2]
# 0              1.034092 -1.0 -0.266020  0.195253
# 1              0.578140 -0.0 -0.034678  0.033475
# 2              0.710929 -0.0 -0.053759  0.050869
# 3              0.955836 -0.0 -0.127166  0.110995
# 4              0.821386 -0.0 -0.077017  0.071085

# %% [markdown]
# ## Group by 50 sites and calculate zscore

# %% [markdown]
# Histogram plot shows that it is normally distributed

# %%
rate_neutral["Window_50"]


rate_neutral_groups = rate_neutral.groupby(np.arange(len(rate_neutral.index))//50)

bin_list = [2, 9, "9_reverse_log"]

columns_header_list = ["p_{bin_number}", "E[p_{bin_number}]", "Var[p_{bin_number}]"]

header_list = [x.format(bin_number = bin_number) for x in columns_header_list for bin_number in bin_list]

# %%
rate_neutral_groups_sum = rate_neutral_groups[header_list].sum()

# remove last column, since it has less than 50 sites
rate_neutral_groups_sum = pd.DataFrame(rate_neutral_groups_sum).iloc[:-1]

for freq_bin in bin_list:
    rate_neutral_groups_sum[f"Zscore_{freq_bin}"] = ((rate_neutral_groups_sum[f"p_{freq_bin}"] - rate_neutral_groups_sum[f"E[p_{freq_bin}]"])/
                                                np.sqrt(rate_neutral_groups_sum[f"Var[p_{freq_bin}]"]))

freq_bin = 2
rate_neutral_groups_sum["Zscore_Gnocchi"] = ((rate_neutral_groups_sum[f"p_{freq_bin}"] - rate_neutral_groups_sum[f"E[p_{freq_bin}]"])/
                                                np.sqrt(np.absolute(rate_neutral_groups_sum[f"E[p_{freq_bin}]"])))

rate_neutral_groups_sum_zscore = pd.melt(rate_neutral_groups_sum, value_vars=['Zscore_2', 'Zscore_9', 'Zscore_9_reverse_log', "Zscore_Gnocchi"], value_name = "Zscore", var_name = "type")

# %%
rate_neutral_groups_sum[['Zscore_2', 'Zscore_9', 'Zscore_9_reverse_log', "Zscore_Gnocchi"]].mean()
# Out:
# Zscore_2               -0.023818
# Zscore_9               -0.029205
# Zscore_9_reverse_log   -0.041059
# Zscore_Gnocchi         -0.018008
# dtype: float64

# %%
sns.set_theme(style="darkgrid")
g = sns.FacetGrid(rate_neutral_groups_sum_zscore, col="type", height=6, margin_titles=True)

g.map(sns.histplot, "Zscore", binwidth=0.5, kde=False, stat='density', label='samples')

g.set_titles(col_template="Metric: {col_name}")
# g.set_titles(col_template="Mu: {col_name}", row_template="window length: {row_name}")

g.fig.suptitle('Chr22 Intergenic Region, Zscore for 50 sites')

def standard_normal(*args, **kwargs):
    # x0, x1 = ax.get_xlim()  # extract the endpoints for the x-axis
    x_pdf = np.linspace(-4, 4, 100)
    y_pdf = scipy.stats.norm.pdf(x_pdf)

    plt.plot(x_pdf, y_pdf, 'r', lw=2, label='pdf')   

g.map(standard_normal)

# %% [markdown]
# ## group by 10,000 sites

# %%
n_sites = 10000
rate_neutral_groups = rate_neutral.groupby(np.arange(len(rate_neutral.index))//n_sites)

bin_list = [2, 9, "9_reverse_log"]

columns_header_list = ["p_{bin_number}", "E[p_{bin_number}]", "Var[p_{bin_number}]"]

header_list = [x.format(bin_number = bin_number) for x in columns_header_list for bin_number in bin_list]

rate_neutral_groups_sum = rate_neutral_groups[header_list].sum()

# remove last column, since it has less than 50 sites
rate_neutral_groups_sum = pd.DataFrame(rate_neutral_groups_sum).iloc[:-1]

for freq_bin in bin_list:
    rate_neutral_groups_sum[f"Zscore_{freq_bin}"] = ((rate_neutral_groups_sum[f"p_{freq_bin}"] - rate_neutral_groups_sum[f"E[p_{freq_bin}]"])/
                                                np.sqrt(rate_neutral_groups_sum[f"Var[p_{freq_bin}]"]))

freq_bin = 2
rate_neutral_groups_sum["Zscore_Gnocchi"] = ((rate_neutral_groups_sum[f"p_{freq_bin}"] - rate_neutral_groups_sum[f"E[p_{freq_bin}]"])/
                                                np.sqrt(np.absolute(rate_neutral_groups_sum[f"E[p_{freq_bin}]"])))

rate_neutral_groups_sum_zscore = pd.melt(rate_neutral_groups_sum, value_vars=['Zscore_2', 'Zscore_9', 'Zscore_9_reverse_log', "Zscore_Gnocchi"], value_name = "Zscore", var_name = "type")

# %%
rate_neutral_groups_sum[["Zscore_2", "Zscore_9", "Zscore_Gnocchi"]].mean()
# Out:
# Zscore_2         -0.349546
# Zscore_9         -0.501419
# Zscore_Gnocchi   -0.276656
# dtype: float64

# %%
sns.set_theme(style="darkgrid")

df_plot = rate_neutral_groups_sum_zscore.copy()
di = {"Zscore_9_reverse_log": "$\sum{log(p_{reverse})}$", "Zscore_Gnocchi": "Poisson", "Zscore_9": "$\sum{p}$", "Zscore_2": "Binomial"}
df_plot = df_plot.replace({"type": di})

g = sns.FacetGrid(df_plot, col="type", height=6, margin_titles=True)

g.map(sns.histplot, "Zscore", binwidth=0.5, kde=False, stat='density', label='samples')

g.set_titles(col_template="{col_name}")
# g.set_titles(col_template="Mu: {col_name}", row_template="window length: {row_name}")

g.fig.suptitle(f'Before Shuffling, Chr22 Intergenic Region, Zscore for {n_sites} sites')

def standard_normal(*args, **kwargs):
    # x0, x1 = ax.get_xlim()  # extract the endpoints for the x-axis
    x_pdf = np.linspace(-4, 4, 100)
    y_pdf = scipy.stats.norm.pdf(x_pdf)

    plt.plot(x_pdf, y_pdf, 'r', lw=2, label='pdf')   

g.map(standard_normal)

# %% [markdown]
# ## Try shuffling

# %%
n_sites = 10000
rate_neutral_groups = rate_neutral_shuffled.groupby(np.arange(len(rate_neutral_shuffled.index))//n_sites)

bin_list = [2, 9, "9_reverse_log"]

columns_header_list = ["p_{bin_number}", "E[p_{bin_number}]", "Var[p_{bin_number}]"]

header_list = [x.format(bin_number = bin_number) for x in columns_header_list for bin_number in bin_list]

rate_neutral_groups_sum = rate_neutral_groups[header_list].sum()

# remove last column, since it has less than 50 sites
rate_neutral_groups_sum = pd.DataFrame(rate_neutral_groups_sum).iloc[:-1]

for freq_bin in bin_list:
    rate_neutral_groups_sum[f"Zscore_{freq_bin}"] = ((rate_neutral_groups_sum[f"p_{freq_bin}"] - rate_neutral_groups_sum[f"E[p_{freq_bin}]"])/
                                                np.sqrt(rate_neutral_groups_sum[f"Var[p_{freq_bin}]"]))

freq_bin = 2
rate_neutral_groups_sum["Zscore_Gnocchi"] = ((rate_neutral_groups_sum[f"p_{freq_bin}"] - rate_neutral_groups_sum[f"E[p_{freq_bin}]"])/
                                                np.sqrt(np.absolute(rate_neutral_groups_sum[f"E[p_{freq_bin}]"])))

rate_neutral_groups_sum_zscore = pd.melt(rate_neutral_groups_sum, value_vars=['Zscore_2', 'Zscore_9', 'Zscore_9_reverse_log', "Zscore_Gnocchi"], value_name = "Zscore", var_name = "type")

# %%
rate_neutral_groups_sum_zscore
# Out:
#                 type    Zscore
# 0           Zscore_2 -0.325144
# 1           Zscore_2 -0.577222
# 2           Zscore_2 -0.505375
# 3           Zscore_2  0.556934
# 4           Zscore_2  0.348967
# ...              ...       ...
# 1027  Zscore_Gnocchi -0.563168
# 1028  Zscore_Gnocchi -0.178999
# 1029  Zscore_Gnocchi -0.870610
# 1030  Zscore_Gnocchi -0.247643
# 1031  Zscore_Gnocchi  0.512085
#
# [1032 rows x 2 columns]

# %%
sns.set_theme(style="darkgrid")

df_plot = rate_neutral_groups_sum_zscore.copy()
di = {"Zscore_9_reverse_log": "$\sum{log(p_{reverse})}$", "Zscore_Gnocchi": "Poisson", "Zscore_9": "$\sum{p}$", "Zscore_2": "Binomial"}
df_plot = df_plot.replace({"type": di})

g = sns.FacetGrid(df_plot, col="type", height=6, margin_titles=True)

g.map(sns.histplot, "Zscore", binwidth=0.5, kde=False, stat='density', label='samples')

g.set_titles(col_template="{col_name}")
# g.set_titles(col_template="Mu: {col_name}", row_template="window length: {row_name}")

g.fig.suptitle(f'After Shuffling, Chr22 Intergenic Region, Zscore for {n_sites} sites')

def standard_normal(*args, **kwargs):
    # x0, x1 = ax.get_xlim()  # extract the endpoints for the x-axis
    x_pdf = np.linspace(-4, 4, 100)
    y_pdf = scipy.stats.norm.pdf(x_pdf)

    plt.plot(x_pdf, y_pdf, 'r', lw=2, label='pdf')   

g.map(standard_normal)

# %% [markdown]
# ## Quantile Quantile Plot

# %%
import numpy as np
import statsmodels.api as sm
import pylab

test = np.random.normal(0,1, 1000)

sm.qqplot(test, line='45')
pylab.show()

# %%
fig = sm.qqplot(rate_neutral_groups_sum["Zscore_9"], line='45')

fig.suptitle("Zscore 9 bins")

pylab.show()

# %%
fig = sm.qqplot(rate_neutral_groups_sum["Zscore_2"], line='45')

fig.suptitle("Zscore 2 bins")
pylab.show()

# %% [markdown]
# ## get outliers

# %%
index = rate_neutral_groups_sum.sort_values("Zscore_9").iloc[0:5].index

# %%
rate_neutral["region"] = np.arange(len(rate_neutral.index))//50

# %%
rate_neutral[rate_neutral["region"].isin(index)].to_csv("neutral_chr22_outlier.tsv", sep = "\t", index = None)

# %% [markdown]
# # Try for chromosome 3

# %%
chrom = 3
filename = os.path.join(scratch_dir, f"whole_genome/p_9/{chrom}/_metadata")
rate = dd.read_parquet(filename.split("_metadata")[0])

# %%
for freq_bin in [9]:
    rate[f"Zscore_{freq_bin}"] = ((rate[f"p_{freq_bin}"] - rate[f"E[p_{freq_bin}]"])/
                                                np.sqrt(rate[f"Var[p_{freq_bin}]"]))

# %%
rate.head()
# Out:
#      Pos     mu Allele_ref Allele  mu_index  AN_total_interpolate  AC_total  \
# 0  12200  0.041          A      C         3             1135038.0       1.0
# 1  12200  0.020          A      T         1             1134263.0       0.0
# 2  12200  0.094          A      G         8             1134263.0       0.0
# 3  12201  0.083          A      G         7             1134263.0       1.0
# 4  12201  0.013          A      T         0             1134263.0       0.0
#
#    filter_int  AF_gnomADv3    AF_ukb            AF  window_100bp  polymorphic  \
# 0           3     0.000007       NaN  8.810278e-07             0            1
# 1           3          NaN       NaN  0.000000e+00             0            0
# 2           3          NaN       NaN  0.000000e+00             0            0
# 3           4          NaN  0.000001  8.816297e-07             0            1
# 4           4          NaN       NaN  0.000000e+00             0            0
#
#    polymorphic_100bp  Neutral    cds  Freq_bin_9  Freq_bin_10       p_9  \
# 0                 90      NaN  False           1            1 -0.949767
# 1                 90      NaN  False           0            0 -0.946241
# 2                 90      NaN  False           0            0 -0.777523
# 3                 90      NaN  False           1            1 -0.897107
# 4                 90      NaN  False           0            0 -0.965322
#
#      E[p_9]  Var[p_9]  Zscore_9
# 0 -0.905086  0.000443 -2.122215
# 1 -0.948165  0.000070  0.230569
# 2 -0.809592  0.003986  0.507928
# 3 -0.826126  0.002978 -1.300691
# 4 -0.966130  0.000019  0.183913

# %%
rate_neutral = rate[~rate["Neutral"].isna()].compute()
rate_neutral = rate_neutral.reset_index(drop = True)
# Out:
# /home/djl34/mambaforge/envs/raklette/lib/python3.9/site-packages/dask/dataframe/_pyarrow_compat.py:17: FutureWarning: Minimal version of pyarrow will soon be increased to 14.0.1. You are using 11.0.0. Please consider upgrading.
#   warnings.warn(
# 2024-05-22 00:26:27,754 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('getitem-b89998a7aff62cc199d4d62c99f91de4', 30))" coro=<Worker.execute() done, defined at /home/djl34/mambaforge/envs/raklette/lib/python3.9/site-packages/distributed/worker_state_machine.py:3610>> ended with CancelledError
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 rate_neutral = rate[~rate["Neutral"].isna()].compute()
#       2 rate_neutral = rate_neutral.reset_index(drop = True)
#
# File ~/mambaforge/envs/raklette/lib/python3.9/site-packages/dask/base.py:342, in DaskMethodsMixin.compute(self, **kwargs)
#     318 def compute(self, **kwargs):
#     319     """Compute this dask collection
#     320
#     321     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     340     dask.compute
#     341     """
# --> 342     (result,) = compute(self, traverse=False, **kwargs)
#     343     return result
#
# File ~/mambaforge/envs/raklette/lib/python3.9/site-packages/dask/base.py:628, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     625     postcomputes.append(x.__dask_postcompute__())
#     627 with shorten_traceback():
# --> 628     results = schedule(dsk, keys, **kwargs)
#     630 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/mambaforge/envs/raklette/lib/python3.9/threading.py:581, in Event.wait(self, timeout)
#     579 signaled = self._flag
#     580 if not signaled:
# --> 581     signaled = self._cond.wait(timeout)
#     582 return signaled
#
# File ~/mambaforge/envs/raklette/lib/python3.9/threading.py:316, in Condition.wait(self, timeout)
#     314 else:
#     315     if timeout > 0:
# --> 316         gotit = waiter.acquire(True, timeout)
#     317     else:
#     318         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/home/djl34/mambaforge/envs/raklette/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/djl34/mambaforge/envs/raklette/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/djl34/mambaforge/envs/raklette/lib/python3.9/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/home/djl34/mambaforge/envs/raklette/lib/python3.9/site-packages/distributed/nanny.py", line 1014, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/home/djl34/mambaforge/envs/raklette/lib/python3.9/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/home/djl34/mambaforge/envs/raklette/lib/python3.9/asyncio/base_events.py", line 634, in run_until_complete
#     self.run_forever()
#   File "/home/djl34/mambaforge/envs/raklette/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#   File "/home/djl34/mambaforge/envs/raklette/lib/python3.9/asyncio/base_events.py", line 1869, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/home/djl34/mambaforge/envs/raklette/lib/python3.9/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
