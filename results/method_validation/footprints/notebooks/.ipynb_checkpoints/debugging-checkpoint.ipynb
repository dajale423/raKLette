# %%
import sys
sys.path.insert(0,'/home/djl34/kl_git/scripts')
from notebook_imports import *

client = Client()

# %%
chrom = 22
rate = os.path.join(scratch_dir, f"results/footprints/split/{chrom}.tsv")
ac = os.path.join(KL_data_dir, f"whole_genome/freq_bins/{chrom}/_metadata")

# %%
rate = dd.read_csv(rate, sep = "\t", dtype={'Spliceai_info': 'object', 'DHS_tissue': 'object', 'footprint_motif_clusters': 'object'})
feature = dd.read_parquet(ac.split("_metadata")[0])
rate = rate.drop(['mu'], axis=1)
rate["Pos"] = rate["Pos"].astype("Int64")

# %%
rate.head()
# Out:
#           index       Pos Allele_ref Allele Spliceai_info  DHS_mean_signal  \
# 0  10961295_G_A  10961295          G      A           NaN         0.329208
# 1  10961295_G_C  10961295          G      C           NaN         0.329208
# 2  10961296_T_A  10961296          T      A           NaN         0.329208
# 3  10961296_T_C  10961296          T      C           NaN         0.329208
# 4  10961296_T_G  10961296          T      G           NaN         0.329208
#
#    DHS_sample  DHS_identifier DHS_tissue  DHS_core_mean_signal  \
# 0        11.0        22.29388  Stromal B              0.329208
# 1        11.0        22.29388  Stromal B              0.329208
# 2        11.0        22.29388  Stromal B              0.329208
# 3        11.0        22.29388  Stromal B              0.329208
# 4        11.0        22.29388  Stromal B              0.329208
#
#    footprint_mean_signal  footprint_samples footprint_motif_clusters  \
# ...

# %%
rate
# Out:
# Dask DataFrame Structure:
#                 index    Pos Allele_ref  Allele Spliceai_info DHS_mean_signal DHS_sample DHS_identifier DHS_tissue DHS_core_mean_signal footprint_mean_signal footprint_samples footprint_motif_clusters footprint_identifier
# npartitions=8
#                object  Int64     object  object        object         float64    float64        float64     object              float64               float64           float64                   object               object
#                   ...    ...        ...     ...           ...             ...        ...            ...        ...                  ...                   ...               ...                      ...                  ...
# ...               ...    ...        ...     ...           ...             ...        ...            ...        ...                  ...                   ...               ...                      ...                  ...
# ...

# %%
feature.head()
# Out:
#         Pos     mu Allele_ref Allele  mu_index  AN_total_interpolate  \
# 0  11253100  2.659          G      A        49             1135310.0
# 1  11253100  0.128          G      T        11             1135225.0
# 2  11253101  0.041          T      A         3             1135225.0
# 3  11253101  0.041          T      G         3             1135225.0
# 4  11253101  0.117          T      C        10             1135140.0
#
#    AC_total  filter_int  AF_gnomADv3    AF_ukb            AF  window_100bp  \
# 0      93.0           4      0.00021  0.000062  8.191595e-05             0
# 1       0.0           4          NaN       NaN  0.000000e+00             0
# 2       2.0           4          NaN  0.000002  1.761765e-06             0
# 3       1.0           4          NaN  0.000001  8.808826e-07             0
# 4   22970.0           4      0.02586  0.019366  2.023539e-02             0
#
#    polymorphic  polymorphic_100bp  Neutral    cds  Freq_bin_9  Freq_bin_10
# ...

# %%
feature
# Out:
# Dask DataFrame Structure:
#                   Pos       mu Allele_ref  Allele mu_index AN_total_interpolate AC_total filter_int AF_gnomADv3   AF_ukb       AF window_100bp polymorphic polymorphic_100bp Neutral   cds Freq_bin_9 Freq_bin_10
# npartitions=12
#                 Int64  float64     object  object    int64              float64  float64      int64     float64  float64  float64        int64       int64             int64   int64  bool    float64     float64
#                   ...      ...        ...     ...      ...                  ...      ...        ...         ...      ...      ...          ...         ...               ...     ...   ...        ...         ...
# ...               ...      ...        ...     ...      ...                  ...      ...        ...         ...      ...      ...          ...         ...               ...     ...   ...        ...         ...
# ...

# %%
rate = rate.merge(feature, on = ['Pos', 'Allele_ref', 'Allele'], how = "inner")
rate = rate[~rate["cds"]]
rate = rate.rename(columns = {"footprint_identifier": "region"})

# %%
rate.head()
# Out:
# /home/djl34/mambaforge/envs/raklette/lib/python3.9/site-packages/dask/dataframe/_pyarrow_compat.py:17: FutureWarning: Minimal version of pyarrow will soon be increased to 14.0.1. You are using 11.0.0. Please consider upgrading.
#   warnings.warn(
# 2024-04-02 14:32:16,516 - distributed.worker - WARNING - Compute Failed
# Key:       ('rename-516b6a2fd196be1dba312717fd3f75ec', 0)
# Function:  subgraph_callable-2d7e7798-f3cb-49a4-a312-1d157afd
# args:      (None, 'getitem-894fa6730ea7430cd02e6da66867845b',                index       Pos Allele_ref  ...    cds Freq_bin_9  Freq_bin_10
# 0       10961580_G_A  10961580          G  ...    NaN        NaN          NaN
# 1       10961583_C_G  10961583          C  ...    NaN        NaN          NaN
# 2       16146007_T_C  16146007          T  ...  False        0.0          0.0
# 3       16146086_A_G  16146086          A  ...  False        0.0          0.0
# 4       16146089_C_T  16146089          C  ...  False        0.0          0.0
# ...

# %%
filename= os.path.join(KL_data_dir, f"whole_genome/freq_bins/{chrom}/_metadata")

rate = dd.read_parquet(filename.split("_metadata")[0])

# %%
rate.head()
# Out:
#         Pos     mu Allele_ref Allele  mu_index  AN_total_interpolate  \
# 0  11253100  2.659          G      A        49             1135310.0
# 1  11253100  0.128          G      T        11             1135225.0
# 2  11253101  0.041          T      A         3             1135225.0
# 3  11253101  0.041          T      G         3             1135225.0
# 4  11253101  0.117          T      C        10             1135140.0
#
#    AC_total  filter_int  AF_gnomADv3    AF_ukb            AF  window_100bp  \
# 0      93.0           4      0.00021  0.000062  8.191595e-05             0
# 1       0.0           4          NaN       NaN  0.000000e+00             0
# 2       2.0           4          NaN  0.000002  1.761765e-06             0
# 3       1.0           4          NaN  0.000001  8.808826e-07             0
# 4   22970.0           4      0.02586  0.019366  2.023539e-02             0
#
#    polymorphic  polymorphic_100bp  Neutral    cds  Freq_bin_9  Freq_bin_10
# ...
